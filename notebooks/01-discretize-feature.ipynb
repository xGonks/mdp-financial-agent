# %%
import pandas as pd
import numpy as np

data = pd.read_csv("../data/external/bitcoin.csv")
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8605 entries, 0 to 8604
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       8605 non-null   str
#  1   Adj Close  8605 non-null   float64
#  2   Close      8605 non-null   float64
#  3   High       8605 non-null   float64
#  4   Low        8605 non-null   float64
#  5   Open       8605 non-null   float64
#  6   Volume     8605 non-null   int64
# dtypes: float64(5), int64(1), str(1)
# memory usage: 470.7 KB

# %%
column = "Open"
n = 100
# strategy uniform

data["new col uniform"] = pd.qcut(x=data[column],
                          q=n,
                          labels=[f"group {i}" for i in range(1, n + 1)])

data["new col uniform"]
# Out:
# 0       group 11
# 1       group 11
# 2       group 12
# 3       group 12
# 4       group 12
#           ...
# 8600     group 8
# 8601     group 8
# 8602     group 9
# 8603     group 8
# 8604     group 8
# Name: new col uniform, Length: 8605, dtype: category
# Categories (100, str): ['group 1' < 'group 2' < 'group 3' < 'group 4' ... 'group 97' < 'group 98' < 'group 99' < 'group 100']

# %%
data[column].shape
# Out:
# (8605,)

# %%
# strategy model based

# %%
data[column]
# Out:
# 0       78582.156250
# 1       77492.882812
# 2       79066.781250
# 3       79449.179688
# 4       79485.093750
#             ...
# 8600    70017.226562
# 8601    70050.226562
# 8602    70256.289062
# 8603    69816.812500
# 8604    69707.179688
# Name: Open, Length: 8605, dtype: float64

# %%
# test
from mdp.utils.discretize_feature import discretize_feature

data["col test"] = discretize_feature(feature=data["Open"],
                                      strategy="quantile-based",
                                      ngroups=100,
                                      prefix=data["Open"].name)

data["col test"]
# Out:
# 0       Open Group 11
# 1       Open Group 11
# 2       Open Group 12
# 3       Open Group 12
# 4       Open Group 12
#             ...
# 8600     Open Group 8
# 8601     Open Group 8
# 8602     Open Group 9
# 8603     Open Group 8
# 8604     Open Group 8
# Name: col test, Length: 8605, dtype: category
# Categories (100, str): ['Open Group 1' < 'Open Group 2' < 'Open Group 3' < 'Open Group 4' ... 'Open Group 97' < 'Open Group 98' < 'Open Group 99' < 'Open Group 100']

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8605 entries, 0 to 8604
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             8605 non-null   str
#  1   Adj Close        8605 non-null   float64
#  2   Close            8605 non-null   float64
#  3   High             8605 non-null   float64
#  4   Low              8605 non-null   float64
#  5   Open             8605 non-null   float64
#  6   Volume           8605 non-null   int64
#  7   new col uniform  8605 non-null   category
#  8   col test         8605 non-null   category
# dtypes: category(2), float64(5), int64(1), str(1)
# memory usage: 497.2 KB
